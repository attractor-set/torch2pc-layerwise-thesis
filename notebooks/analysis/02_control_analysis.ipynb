# %% [markdown]
# # Анализ контрольного шлюза
#
# Анализ результатов H0/H1, полученных в контролируемых CPU/GPU-запусках.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
PROJECT_ROOT = Path('../..').resolve()
RESULTS = PROJECT_ROOT / 'results'
REGISTRY = PROJECT_ROOT / 'experiments' / 'registry.csv'

# %%
files = sorted((RESULTS / 'summaries').glob('h*_*.csv'))
[(path.name, pd.read_csv(path).shape) for path in files]
