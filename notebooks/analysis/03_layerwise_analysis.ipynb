# %% [markdown]
# # Послойный анализ
#
# Анализ градиентов, CKA и RSA по замороженным контрольным точкам.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
PROJECT_ROOT = Path('../..').resolve()
RESULTS = PROJECT_ROOT / 'results'
REGISTRY = PROJECT_ROOT / 'experiments' / 'registry.csv'

# %%
files = sorted((RESULTS / 'summaries').glob('*layer*.csv'))
print([path.name for path in files])
