# %% [markdown]
# # Рисунки для публикации
#
# Формирование итоговых рисунков только из замороженных агрегированных таблиц.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
PROJECT_ROOT = Path('../..').resolve()
RESULTS = PROJECT_ROOT / 'results'
REGISTRY = PROJECT_ROOT / 'experiments' / 'registry.csv'

# %%
print('Каталог рисунков:', RESULTS / 'figures')
